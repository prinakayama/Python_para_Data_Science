# %% [markdown]
# <a href="https://www.kaggle.com/code/prinaka/analise-dados?scriptVersionId=191208426" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# Antes de qualquer coisa, vamos importar a biblioteca Pandas
import pandas as pd

# %%
# **1. Criação de um dataset**

# %%
# Criação de um DataFrame do resultado de uma votação.
pd.DataFrame({'Sim':[10,15], 'Nao':[21, 4]})
# Out:
#    Sim  Nao
# 0   10   21
# 1   15    4

# %%
# Criação de uma Serie tem apenas uma lista. Vamos criar uma Serie:
pd.Series([10,15])
# Out:
# 0    10
# 1    15
# dtype: int64

# %%
## 1. Exercício

# %%
# 1.1 Crie um DataFrame que tenha 3 colunas e 2 duas linhas com o nome: vendas
df = pd.DataFrame({'Produto':['Chocolate','Banana'], 'Quantidade':[200,80],'Preco':[3.00,0.5]})
df
# Out:
#      Produto  Quantidade  Preco
# 0  Chocolate         200    3.0
# 1     Banana          80    0.5

# %%
# 1.2 Crie uma Serie que contenha o total dos produtos. Com os seguintes valores: 600, 40
pd.Series([600,40])
# Out:
# 0    600
# 1     40
# dtype: int64

# %% [markdown]
# # 2. Salvar arquivo csv
# ## 2.Exercicio

# %%
# 2. Salve o dataframe vendas criado no exercício 1.1 num arquivo csv chamado `vendas`
df.to_csv('vendas.csv')

# %% [markdown]
# # 3. Abrir dados existente

# %%
import numpy as np 
import pandas as pd 

import os

# Lista os datasets no diretório de entrada do Kaggle
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        if filename.endswith('.csv') or filename.endswith('.json') or filename.endswith('.xlsx'):
            print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/licitacao/202401_EmpenhosRelacionados.csv
# /kaggle/input/licitacao/202401_ParticipantesLicitao.csv
# /kaggle/input/licitacao/202401_ItemLicitao.csv
# /kaggle/input/licitacao/202401_Licitao.csv

# %%
# !ls
# Out:
# vendas.csv

# %% [markdown]
# ## 3.1 Como abrir arq Excel

# %%
# Omite os warnings.. por enquanto
import warnings
warnings.filterwarnings('ignore')

# Importa o pandas
import pandas as pd

# Vamos abrir o arquivo em Excel (.xlsx) de uasgs
uasgs = pd.ExcelFile('/kaggle/input/nome_arq.xlsx')

# Transforma de Excel para DataFrame. O Parâmetro aqui é o nome da aba (Sheet 1)
uasgs = uasgs.parse('itens') 

# Visualiza as primeiras linhas do dataset 
uasgs.head()

# %%
# DICA ESPECIAL: Mostrar mais colunas, opção do Pandas para não aparecer o "..." 
pd.set_option('display.max_columns', 500)
uasgs.head()

# %% [markdown]
# ## 3.2 Abrir arquivos csv

# %%
# Importa o arquivo CSV de licitação com o nome de licit
licit = pd.read_csv('../input/df-licitacoes/202401_Licitao.csv', encoding='latin1', delimiter=';')# Visualiza as primeiras linhas do dataset 
licit.head()
# Out:
#    Número Licitação  Código UG                                      Nome UG  \
# 0             12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 1             12023     135008                           EMBRAPA/CPAF-AMAPA
# 2             12023     135020                                 EMBRAPA/CTAA
# 3             12023     135039                                 EMBRAPA/CPAC
# 4             12023     152237                       CAMPUS ARRAIAL DO CABO
#
#    Código Modalidade Compra             Modalidade Compra    Número Processo  \
# 0                         5                        Pregão  21030.002858/2023
# 1                         7  Inexigibilidade de Licitação  21157001423202338
# 2                         7  Inexigibilidade de Licitação  21152.001449/2023
# 3                         7  Inexigibilidade de Licitação  21167.001652/2023
# 4                       -99    Pregão - Registro de Preço  23826000189202327
#
# ...

# %% [markdown]
# ## 3. Exercicio

# %%
# 3. Faça a importação do arquivo CSV de itemLicitacao e visualize suas primeiras linhas.

item_licit = pd.read_csv('../input/df-licitacoes/202401_ItemLicitao.csv', encoding='latin1', delimiter=';')# Visualiza as primeiras linhas do dataset 
item_licit.head()
# Out:
#    Número Licitação  Código UG                                      Nome UG  \
# 0             12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 1             12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 2             12023     135008                           EMBRAPA/CPAF-AMAPA
# 3             12023     135020                                 EMBRAPA/CTAA
# 4             12023     135020                                 EMBRAPA/CTAA
#
#    Código Modalidade Compra             Modalidade Compra    Número Processo  \
# 0                         5                        Pregão  21030.002858/2023
# 1                         5                        Pregão  21030.002858/2023
# 2                         7  Inexigibilidade de Licitação  21157001423202338
# 3                         7  Inexigibilidade de Licitação  21152.001449/2023
# 4                         7  Inexigibilidade de Licitação  21152.001449/2023
#
# ...

# %% [markdown]
# # 4 Renomear e combinar datasets

# %% [markdown]
# ## 4.1 Exercicio

# %%
# 4.1 Renomeie a coluna Código Modalidade Compra do dataset ItemLicitacao para codigomodalidade

item_licit = licit.rename(columns={'Código Modalidade Compra': 'codigomodalidade'})

# %%
item_licit.head()
# Out:
#    Número Licitação  Código UG                                      Nome UG  \
# 0             12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 1             12023     135008                           EMBRAPA/CPAF-AMAPA
# 2             12023     135020                                 EMBRAPA/CTAA
# 3             12023     135039                                 EMBRAPA/CPAC
# 4             12023     152237                       CAMPUS ARRAIAL DO CABO
#
#    codigomodalidade             Modalidade Compra    Número Processo  \
# 0                 5                        Pregão  21030.002858/2023
# 1                 7  Inexigibilidade de Licitação  21157001423202338
# 2                 7  Inexigibilidade de Licitação  21152.001449/2023
# 3                 7  Inexigibilidade de Licitação  21167.001652/2023
# 4               -99    Pregão - Registro de Preço  23826000189202327
#
#                                               Objeto  \
# ...

# %%
# 4.2 Faça a combinação para juntar os datasets de licitações e modalidades e salve num novo dataset chamado licitm
licitm = pd.merge(licit, item_licit, on='Número Licitação')

# %%
licitm.head()
# Out:
#    Número Licitação  Código UG_x                                    Nome UG_x  \
# 0             12023       130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 1             12023       130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 2             12023       130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 3             12023       130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 4             12023       130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
#
#    Código Modalidade Compra Modalidade Compra_x  Número Processo_x  \
# 0                         5              Pregão  21030.002858/2023
# 1                         5              Pregão  21030.002858/2023
# 2                         5              Pregão  21030.002858/2023
# 3                         5              Pregão  21030.002858/2023
# 4                         5              Pregão  21030.002858/2023
#
#                                             Objeto_x  \
# ...

# %% [markdown]
# # 5 Selecionar subconjuntos de um dataset
# ##### .loc: retorna pelo nome (textual)
# ##### .iloc: retorna pela posição (numérico)
# ##### [ ]: retorna um elemento ou o range de elementos. Sendo [linhas/indices, colunas]

# %%
# EXEMPLOS

# Retorna apenas a coluna dataPublicacao 
licit['Data Abertura']

# Retorna apenas a segunda data
licit['Data Abertura'][1]
licit['Data Abertura'].iloc[1]

# Retorna as primeiras 5 linhas
licit[:5]

# Retorna apenas a ultima coluna
licit.iloc[:,-1]

# Cria um dataset de exemplo apenas com as linhas 3 e 5 das colunas dataPublicacao e situacao
exemplo = licit.loc[[3,5],['Data Abertura','Situação Licitação']]
exemplo

# Retorna um dataset contendo apenas publicacoes do ano de 2024. Dataset com o nome de: a2019
a2024 = licit[licit['Data Abertura'].fillna('').str.contains('2024')]
a2024.head()
# Out:
#     Número Licitação  Código UG                                  Nome UG  \
# 4              12023     152237                   CAMPUS ARRAIAL DO CABO
# 12             12023     158295                   IFMA/CAMPUS ACAILANDIA
# 15             12023     158560                  IFAM - CAMPUS PARINTINS
# 30             12023     784320         CAPITANIA DOS PORTOS DO MARANHAO
# 32             22023     114619  SUPERINTENDENCIA ESTADUAL DO IBGE NO ES
#
#     Código Modalidade Compra           Modalidade Compra    Número Processo  \
# 4                        -99  Pregão - Registro de Preço  23826000189202327
# 12                       -99  Pregão - Registro de Preço  23249031243202387
# 15                         5                      Pregão  23443010516202353
# 30                       -99  Pregão - Registro de Preço  63036001874202219
# 32                         5                      Pregão  03632000198202388
#
#                                                Objeto  \
# ...

# %% [markdown]
# ## 5 Exercicios

# %%
# 5.1. Crie um dataset apenas com as colunas dataPublicacao e situacao de todos do ano de 2018: a2018
a2018 = licit[licit['Data Abertura'].fillna('').str.contains('2018')][['Data Abertura', 'Situação Licitação']]
a2018.head()
# Out:
# Empty DataFrame
# Columns: [Data Abertura, Situação Licitação]
# Index: []

# %% [markdown]
# # 6 Manipulacao de datas

# %%
# Importa datetime
import datetime

# Imprime a data e hora
print(datetime.datetime.now())

# Imprime apenas a data
print(datetime.date.today())

# Imprime apenas o ano
print(datetime.date.today().year)

# Imprime apenas o mês
print(datetime.date.today().month)

# Imprime apenas o dia
print(datetime.date.today().day)

# Imprime apenas a hora
print(datetime.datetime.today().hour)
# Out:
# 2024-08-04 23:26:43.959679
# 2024-08-04
# 2024
# 8
# 4
# 23

# %%
# Outro exemplo para imprimir o ano
agora = datetime.datetime.now()
agora.strftime('%Y')
# Out:
# '2024'

# %%
# Convertendo o formato da data de 2024-08-04 para 04/08/2024
datetime.datetime.strptime("2024-08-04", '%Y-%m-%d').strftime('%d/%m/%Y')
# Out:
# '04/08/2024'

# %%
# Cria uma nova coluna com a data formatada de 04/08/2024 para 04-08-2024
licit['Data Formatada'] = [datetime.datetime.strptime(str(x), '%d/%m/%Y').strftime('%d-%m-%Y') if isinstance(x, str) else x for x in licit['Data Abertura']]

# %% [markdown]
# ## 6 Exercicio

# %%
# 1. Crie uma nova coluna no dataset de licit para o ano de publicacao: ano
licit['Ano'] = pd.to_datetime(licit['Data Abertura'], dayfirst=True).dt.year

# %%
licit.head()
# Out:
#    Número Licitação  Código UG                                      Nome UG  \
# 0             12023     130094  SUPERINT.DE AGRICULTURA E PECUARIA - SFA/PA
# 1             12023     135008                           EMBRAPA/CPAF-AMAPA
# 2             12023     135020                                 EMBRAPA/CTAA
# 3             12023     135039                                 EMBRAPA/CPAC
# 4             12023     152237                       CAMPUS ARRAIAL DO CABO
#
#    Código Modalidade Compra             Modalidade Compra    Número Processo  \
# 0                         5                        Pregão  21030.002858/2023
# 1                         7  Inexigibilidade de Licitação  21157001423202338
# 2                         7  Inexigibilidade de Licitação  21152.001449/2023
# 3                         7  Inexigibilidade de Licitação  21167.001652/2023
# 4                       -99    Pregão - Registro de Preço  23826000189202327
#
# ...

# %% [markdown]
# # 7 Agrupar e ordenar
# ### df.groupby(["coluna"]).coluna.funcao() : para executar uma função em uma coluna
# ### df.groupby(["coluna1", "coluna2"]).coluna.funcao() : para executar uma função em multiplas colunas
# ### df.groupby(["coluna"]).coluna.agg[[funcao1, funcao2]) : para executar multiplas funções em uma coluna
# ### df.sort_values(by="coluna", ascending=False): para ordenar uma coluna do maior valor para o menor
# ### df.sort_values(by=["coluna1","coluna2"]): para ordenar por mais de uma coluna

# %% [markdown]
# ### & Exercicios

# %%
# 1. Faça um agrupamento para descobrir a quantidade de licitacoes publicadas por ano
licit.groupby('Ano').size()
# Out:
# Ano
# 2019.0      62
# 2020.0      50
# 2021.0      20
# 2022.0      28
# 2023.0    1332
# 2024.0     634
# dtype: int64

# %%
# 2. Crie um DataFrame com o resultado da quantidade de licitacoes por ano
licitacoes_por_ano = licit.groupby('Ano').size().reset_index(name='quantidade_licitacoes')
licitacoes_por_ano
# Out:
#       Ano  quantidade_licitacoes
# 0  2019.0                     62
# 1  2020.0                     50
# 2  2021.0                     20
# 3  2022.0                     28
# 4  2023.0                   1332
# 5  2024.0                    634

# %%
# 3. Ordene os valores e responda: Qual foi o ano que teve o menor número de licitacoes publicadas?
licitacoes_por_ano.sort_values('quantidade_licitacoes').head(1)
#1 (sort_values)Ordena o DataFrame, (qtd_lic)em ordem crescente, (head(1))seleciona a primeira linha do DataFrame ordenado
# Out:
#       Ano  quantidade_licitacoes
# 2  2021.0                     20

# %% [markdown]
# # 8 Valores Faltantes
# ### Os valores faltantes pode prejudicar a analise, porque podem ser ignorados pelas operacoes count, sum, etc. Ex: Nan (not a number)
# ### A melhor forma de lidar com os dados faltantes eh:
# #### Inserção: preencher com os valores faltantes, inserir a média ou mediana ou moda dos valores (para numéricos), usar um modelo preditivo para estimar os valores faltantes ou simplesmente informar que é um valor Desconhecido (para dados categóricos e textuais).
# #### Exclusão Parcial: excluir os registros que estão com valores faltantes.
# ### A sintaxe Python usada:
#
# ## Para selecionar NaN: pd.isnull()
# ## Para substituir valores NaN: df.fillna()
# ## Para substituir NaN pela média: df.fillna(df.mean(), inplace=True)
# ## Para substituir valores presentes por outros valores: `pd.replace("valor","novo_valor")
# ## Para remover os registros NaN: df.dropna(inplace=True)

# %%
# Verifica se tem algum valor NaN no Dataset inteiro
licit.isnull().sum()

# Verifica a quantidade de valores NaN apenas em uma coluna
licit['Data Abertura'].isnull().sum()
# Out:
# 407

# %% [markdown]
# ## 8. Exercicios

# %%
# 1. Importa o arquivo CSV de itens licitação com o nome de item

# %%
# 2. Verifica se tem algum valor NaN

# %%
# 3 Apague os registros NaN de licit. Quantas linhas restou no dataset?
